# %%
# !pip install deepface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepface in c:\users\raush\appdata\roaming\python\python310\site-packages (0.0.74)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (1.4.2)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (9.1.0)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (4.5.5.64)
# Requirement already satisfied: keras>=2.2.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (2.9.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (2.1.1)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (2.9.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (4.64.0)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (4.4.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (0.0.10)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from deepface) (1.22.3)
# Requirement already satisfied: click>=8.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (8.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (3.1.1)
# Requirement already satisfied: six in c:\users\raush\appdata\roaming\python\python310\site-packages (from gdown>=3.10.1->deepface) (1.16.0)
# Requirement already satisfied: filelock in c:\users\raush\appdata\roaming\python\python310\site-packages (from gdown>=3.10.1->deepface) (3.6.0)
# Requirement already satisfied: requests[socks] in c:\users\raush\appdata\roaming\python\python310\site-packages (from gdown>=3.10.1->deepface) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\raush\appdata\roaming\python\python310\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from pandas>=0.23.4->deepface) (2022.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.44.0)
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (58.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (0.24.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (4.2.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: packaging in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (21.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (2.9.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (3.20.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.14.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (13.0.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (3.6.0)
# Requirement already satisfied: colorama in c:\users\raush\appdata\roaming\python\python310\site-packages (from tqdm>=4.30.0->deepface) (0.4.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (2.6.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\raush\appdata\roaming\python\python310\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\raush\appdata\roaming\python\python310\site-packages (from packaging->tensorflow>=1.9.0->deepface) (3.0.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raush\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raush\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\raush\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\raush\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\raush\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\raush\appdata\roaming\python\python310\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\raush\appdata\roaming\python\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (3.2.0)

# %%
from deepface import DeepFace

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('happy.jpg')

# %%
predictions = DeepFace.analyze(img,actions=['emotion'])
# Out:
# 1/1 [==============================] - 0s 187ms/step

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
cv2.putText(img,predictions['dominant_emotion'],(0,50),font,1,(0,0,255),2,cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[246, 255, 254],
#         [243, 255, 254],
#         [204, 226, 221],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[231, 232, 230],
#         [255, 255, 254],
#         [255, 255, 254],
#         ...,
#         [251, 251, 251],
#         [248, 248, 248],
#         [255, 255, 255]],
#
#        [[255, 255, 254],
#         [247, 239, 239],
#         [255, 253, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
while True:
    ret,frame = cap.read()
    result = DeepFace.analyze(frame,actions=['emotion'])
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for x,y,w,h in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame,result['dominant_emotion'],(50,50),font,3,(0,0,255),2,cv2.LINE_4)
    cv2.imshow('Orginal Video',frame)
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
