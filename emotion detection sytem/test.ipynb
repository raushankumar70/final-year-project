# %%
from deepface import DeepFace

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %% [markdown]
# load image

# %%
img1=cv2.imread(r'E:\test11\python\projects\emotion detection sytem\train\image\a2ec0259295c717ebfebb4c2fe86025c.jpg')

# %%
img1

# %%
plt.imshow(img1[::,::,::-1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 plt.imshow(img1[::,::,::-1])
#       2 plt.show()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
l=[[1,2,3,4],['a','b','c','d']]
import numpy as np
data=np.array(l)

# %%
data[::-1,::-1]
# Out:
# array([['d', 'c', 'b', 'a'],
#        ['4', '3', '2', '1']], dtype='<U11')

# %% [raw]
# analyze the image

# %%
result=DeepFace.analyze(img1,actions=['emotion'])
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 result=DeepFace.analyze(img1,actions=['emotion'])
#       2 result
#
# File ~\AppData\Roaming\Python\Python310\site-packages\deepface\DeepFace.py:391, in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     389 if action == 'emotion':
#     390 	emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 391 	img, region = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     393 	emotion_predictions = models['emotion'].predict(img)[0,:]
#     395 	sum_of_predictions = emotion_predictions.sum()
#
# ...

# %%
result['dominant_emotion']
# Out:
# 'angry'

# %%
type(result['emotion'])
# Out:
# dict

# %%
name,val=result['emotion'].keys(),result['emotion'].values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 name,val=result['emotion'].keys(),result['emotion'].values()
#
# NameError: name 'result' is not defined

# %%
name,val
# Out:
# (dict_keys(['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']),
#  dict_values([95.65852258554236, 0.01223256476957737, 3.710087237363293, 0.004300800612197481, 0.5498914375836514, 0.009083823347571022, 0.05588400277921574]))

# %%
plt.bar(name, val)
plt.suptitle('Emotion')
plt.show()
pl

# %% [raw]
# Camera working time

# %%
cap=cv2.VideoCapture(0)

ret,img=cap.read()
cv2.imshow('webcam',img)
k=cv2.waitKey(10)
cap.release()
cv2.destroyAllWindows()

# %%
y=randint(1000000,2000000)

plt.imshow(img[:,:,::-1])
plt.show()
plt.savefig((str(y)+".png"))

# %%
from random import randint
import os

# %%
cv2.imwrite(("train/"+str(y)+".png"), img)
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1084/4039960942.py in <module>
# ----> 1 print(os.listdir(directory))
#
# NameError: name 'directory' is not defined

# %%
y=randint(1000000,2000000)
file="upload\"+str(y)+.png
cv2.imwrite(file, img)
# Out:
# 1946917

# %%
print(y)
# Out:
# 2022-05-09 17:37:21.117932

# %%
plt.savefig(img,(str(y)+".png"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11560/2446051777.py in <module>
# ----> 1 plt.savefig(img,(str(y)+".png"))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# TypeError: savefig() takes 2 positional arguments but 3 were given

# %%
result=DeepFace.analyze(img,actions=['emotion'])
result
# Out:
# {'emotion': {'angry': 0.3254559783536779,
#   'disgust': 0.00011780400220268629,
#   'fear': 0.05892414252380386,
#   'happy': 99.27163119743057,
#   'sad': 0.10268411745483383,
#   'surprise': 0.0030762914335426424,
#   'neutral': 0.2381104885033064},
#  'dominant_emotion': 'happy',
#  'region': {'x': 300, 'y': 45, 'w': 251, 'h': 251}}

# %%
y=result["emotion"]

# %%
y
# Out:
# {'angry': 0.3254559783536779,
#  'disgust': 0.00011780400220268629,
#  'fear': 0.05892414252380386,
#  'happy': 99.27163119743057,
#  'sad': 0.10268411745483383,
#  'surprise': 0.0030762914335426424,
#  'neutral': 0.2381104885033064}

# %%
sort(y,index=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20112/2220747431.py in <module>
# ----> 1 sort(y,index=1)
#
# NameError: name 'sort' is not defined

# %%
# Creates a sorted dictionary (sorted by
y

# %%
y.keys()

# %%
sorted(y.items(),key=lambda x:x[1])

# %%
x=sorted(y.items(),key=lambda x:x[1])  
x

# %%
z=x[-1:-4:-1]

# %%
for i in z:
    print(i[0])
